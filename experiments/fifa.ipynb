# %%
from pandas import read_csv
import numpy as np

# %%
playerData = read_csv('PlayerPersonalData.csv')

# %%
playerData.columns
# Out:
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'ID', u'Name', u'Age', u'Photo',
#        u'Nationality', u'Flag', u'Overall', u'Potential', u'Club',
#        u'Club Logo', u'Value', u'Wage', u'Special'],
#       dtype='object')

# %%
playerData[['Name', 'Overall', 'Value', 'Nationality']]
# Out:
#                     Name  Overall   Value          Nationality
# 0      Cristiano Ronaldo       94  €95.5M             Portugal
# 1               L. Messi       93   €105M            Argentina
# 2                 Neymar       92   €123M               Brazil
# 3              L. Suárez       92    €97M              Uruguay
# 4               M. Neuer       92    €61M              Germany
# 5         R. Lewandowski       91    €92M               Poland
# 6                 De Gea       90  €64.5M                Spain
# 7              E. Hazard       90  €90.5M              Belgium
# 8               T. Kroos       90    €79M              Germany
# 9             G. Higuaín       90    €77M            Argentina
# 10          Sergio Ramos       90    €52M                Spain
# 11          K. De Bruyne       89    €83M              Belgium
# 12           T. Courtois       89    €59M              Belgium
# 13            A. Sánchez       89  €67.5M                Chile
# ...

# %%
# Pythonic Query
playerData[playerData['Special'] > 2000]
# Out:
#       Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0              0             0   20801  Cristiano Ronaldo   32
# 1              1             1  158023           L. Messi   30
# 2              2             2  190871             Neymar   25
# 3              3             3  176580          L. Suárez   30
# 5              5             5  188545     R. Lewandowski   28
# 7              7             7  183277          E. Hazard   26
# 8              8             8  182521           T. Kroos   27
# 10            10            10  155862       Sergio Ramos   31
# 11            11            11  192985       K. De Bruyne   26
# 13            13            13  184941         A. Sánchez   28
# 14            14            14  177003          L. Modrić   31
# 15            15            15  173731            G. Bale   27
# 16            16            16  153079          S. Agüero   29
# 19            19            19  211110          P. Dybala   23
# ...

# %%
# SQL-like query
playerData.query('Special > 2000')
# Out:
#       Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0              0             0   20801  Cristiano Ronaldo   32
# 1              1             1  158023           L. Messi   30
# 2              2             2  190871             Neymar   25
# 3              3             3  176580          L. Suárez   30
# 5              5             5  188545     R. Lewandowski   28
# 7              7             7  183277          E. Hazard   26
# 8              8             8  182521           T. Kroos   27
# 10            10            10  155862       Sergio Ramos   31
# 11            11            11  192985       K. De Bruyne   26
# 13            13            13  184941         A. Sánchez   28
# 14            14            14  177003          L. Modrić   31
# 15            15            15  173731            G. Bale   27
# 16            16            16  153079          S. Agüero   29
# 19            19            19  211110          P. Dybala   23
# ...

# %%
map(string playerData['Wage'].values
# Out:
# array(['\xe2\x82\xac565K', '\xe2\x82\xac565K', '\xe2\x82\xac280K', ...,
#        '\xe2\x82\xac1K', '\xe2\x82\xac1K', '\xe2\x82\xac1K'], dtype=object)
